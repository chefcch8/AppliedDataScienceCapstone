# %% [markdown]
# # Applied Data Science Capstone
# ## Battle of Neiborhood Location
# ### Created by dvh  -  Oct 2018

# %% [markdown]
# ## Scrape the Wikipedia page

# %%
import io
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import json # library to handle JSON files
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium # map rendering library

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Table of postal codes

# %%
source = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(source,'lxml')
table = soup.find('table', class_='wikitable sortable')
table_rows = table.find_all('tr')
res = []
for tr in table_rows:
    td = tr.find_all('td')
    row = [tr.text.strip() for tr in td if tr.text.strip()]
    if row:
        res.append(row)

# %% [markdown]
# ### Transform the data into a pandas dataframe

# %%
df = pd.DataFrame(res, columns=["Postcode", "Borough", "Neighbourhood"])
df = df[df.Borough != 'Not assigned']
idx=df.index[df.Neighbourhood == 'Not assigned']
df['Neighbourhood'] = df['Borough'].where(df['Neighbourhood']=='Not assigned', df['Neighbourhood'])
df=df.groupby(['Postcode','Borough'])['Neighbourhood'].apply(', '.join).reset_index()

# %% [markdown]
# ### Get the latitude and the longitude coordinates of each neighborhood.

# %%
url="https://cocl.us/Geospatial_data/Geospatial_Coordinates.csv"
file=requests.get(url).content

# %%
df2=pd.read_csv('Geospatial_Coordinates.csv')
df2.columns = ['Postcode', 'Latitude','Longitude']
df1 = pd.merge(df, df2, on='Postcode')

# %%
address = 'Toronto'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto City are {}, {}.'.format(latitude, longitude))
borough_Toronto_data = df1[df1['Borough'].str.contains("Toronto")].reset_index(drop=True)
borough_Toronto_data.head()
# Out:
# /home/dvh/anaconda3/lib/python3.6/site-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# The geograpical coordinate of Toronto City are 43.653963, -79.387207.
#   Postcode          Borough                   Neighbourhood   Latitude  \
# 0      M4E     East Toronto                     The Beaches  43.676357
# 1      M4K     East Toronto    The Danforth West, Riverdale  43.679557
# 2      M4L     East Toronto  The Beaches West, India Bazaar  43.668999
# 3      M4M     East Toronto                 Studio District  43.659526
# 4      M4N  Central Toronto                   Lawrence Park  43.728020
#
#    Longitude
# 0 -79.293031
# 1 -79.352188
# 2 -79.315572
# 3 -79.340923
# 4 -79.388790

# %% [markdown]
# ### Create a map of Toronto with neighborhoods superimposed on top.

# %%
# create map of Manhattan using latitude and longitude values
map_borough_Toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(borough_Toronto_data['Latitude'], borough_Toronto_data['Longitude'], borough_Toronto_data['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_borough_Toronto)  
    
map_borough_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'VI1HZZN4HJQHMPBKYZUQ52OQVJFP3LLJ03ITAIQXTMEC3S1M' # your Foursquare ID
CLIENT_SECRET = 'EJ2C0NQ31QONYYFULJLYDIOV4NB22WI1TK4XDUQEXFKVVM2V' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# type your answer here
# Out:
# Your credentails:
# CLIENT_ID: VI1HZZN4HJQHMPBKYZUQ52OQVJFP3LLJ03ITAIQXTMEC3S1M
# CLIENT_SECRET:EJ2C0NQ31QONYYFULJLYDIOV4NB22WI1TK4XDUQEXFKVVM2V

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# type your answer here

Toronto_venues = getNearbyVenues(names=borough_Toronto_data['Neighbourhood'],
                                   latitudes=borough_Toronto_data['Latitude'],
                                   longitudes=borough_Toronto_data['Longitude']
                                  )
# Out:
# The Beaches
# The Danforth West, Riverdale
# The Beaches West, India Bazaar
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park, Summerhill East
# Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West
# Rosedale
# Cabbagetown, St. James Town
# Church and Wellesley
# Harbourfront, Regent Park
# Ryerson, Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Adelaide, King, Richmond
# Harbourfront East, Toronto Islands, Union Station
# Design Exchange, Toronto Dominion Centre
# Commerce Court, Victoria Hotel
# Roselawn
# Forest Hill North, Forest Hill West
# The Annex, North Midtown, Yorkville
# Harbord, University of Toronto
# Chinatown, Grange Park, Kensington Market
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara
# Stn A PO Boxes 25 The Esplanade
# First Canadian Place, Underground city
# Christie
# Dovercourt Village, Dufferin
# Little Portugal, Trinity
# Brockton, Exhibition Place, Parkdale Village
# High Park, The Junction South
# Parkdale, Roncesvalles
# Runnymede, Swansea
# Business reply mail Processing Centre969 Eastern

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
# one hot encoding
Toronto_onehot = pd.get_dummies(Toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
Toronto_onehot['Neighbourhood'] = Toronto_venues['Neighbourhood'] 

# move neighborhood column to the first column
fixed_columns = [Toronto_onehot.columns[-1]] + list(Toronto_onehot.columns[:-1])
Toronto_onehot = Toronto_onehot[fixed_columns]

Toronto_grouped = Toronto_onehot.groupby('Neighbourhood').mean().reset_index()

# %%
num_top_venues = 5

for hood in Toronto_grouped['Neighbourhood']:
    print("----"+hood+"----")
    temp = Toronto_grouped[Toronto_grouped['Neighbourhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Adelaide, King, Richmond----
#              venue  freq
# 0      Coffee Shop  0.07
# 1             Café  0.06
# 2  Thai Restaurant  0.04
# 3       Steakhouse  0.04
# 4              Gym  0.04
#
#
# ----Berczy Park----
#             venue  freq
# 0     Coffee Shop  0.07
# 1    Cocktail Bar  0.05
# 2  Farmers Market  0.04
# 3      Restaurant  0.04
# 4          Bakery  0.04
#
#
# ----Brockton, Exhibition Place, Parkdale Village----
#             venue  freq
# 0     Coffee Shop  0.14
# 1  Breakfast Spot  0.09
# 2            Café  0.09
# 3   Burrito Place  0.05
# 4         Stadium  0.05
#
#
# ----Business reply mail Processing Centre969 Eastern----
#               venue  freq
# 0               Spa  0.06
# 1     Auto Workshop  0.06
# 2        Comic Shop  0.06
# 3  Recording Studio  0.06
# 4        Restaurant  0.06
#
#
# ----CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara----
#               venue  freq
# 0    Airport Lounge  0.14
# 1  Airport Terminal  0.14
# 2   Airport Service  0.14
# 3             Plane  0.07
# 4   Harbor / Marina  0.07
#
#
# ----Cabbagetown, St. James Town----
#                 venue  freq
# 0         Coffee Shop  0.08
# 1          Restaurant  0.08
# 2                 Pub  0.04
# 3   Indian Restaurant  0.04
# 4  Italian Restaurant  0.04
#
#
# ----Central Bay Street----
#                 venue  freq
# 0         Coffee Shop  0.14
# 1                Café  0.06
# 2  Italian Restaurant  0.05
# 3      Ice Cream Shop  0.04
# 4     Bubble Tea Shop  0.04
#
#
# ----Chinatown, Grange Park, Kensington Market----
#                            venue  freq
# 0                           Café  0.08
# 1  Vegetarian / Vegan Restaurant  0.06
# 2                            Bar  0.06
# 3             Chinese Restaurant  0.05
# 4             Mexican Restaurant  0.04
#
#
# ----Christie----
#                 venue  freq
# 0                Café  0.19
# 1       Grocery Store  0.19
# 2                Park  0.12
# 3         Coffee Shop  0.06
# 4  Athletics & Sports  0.06
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0  Japanese Restaurant  0.08
# 1          Coffee Shop  0.06
# 2     Sushi Restaurant  0.05
# 3              Gay Bar  0.05
# 4           Restaurant  0.03
#
#
# ----Commerce Court, Victoria Hotel----
#                  venue  freq
# 0          Coffee Shop  0.14
# 1                Hotel  0.06
# 2                 Café  0.06
# 3           Restaurant  0.05
# 4  American Restaurant  0.04
#
#
# ----Davisville----
#                 venue  freq
# 0        Dessert Shop  0.11
# 1      Sandwich Place  0.08
# 2         Pizza Place  0.06
# 3  Seafood Restaurant  0.06
# 4                Café  0.06
#
#
# ----Davisville North----
#                venue  freq
# 0        Pizza Place  0.12
# 1               Park  0.12
# 2  Food & Drink Shop  0.12
# 3     Breakfast Spot  0.12
# 4       Burger Joint  0.12
#
#
# ----Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West----
#                venue  freq
# 0                Pub  0.14
# 1        Coffee Shop  0.14
# 2        Pizza Place  0.07
# 3   Sushi Restaurant  0.07
# 4  Convenience Store  0.07
#
#
# ----Design Exchange, Toronto Dominion Centre----
#                  venue  freq
# 0          Coffee Shop  0.15
# 1                Hotel  0.10
# 2                 Café  0.07
# 3  American Restaurant  0.04
# 4           Sports Bar  0.03
#
#
# ----Dovercourt Village, Dufferin----
#                    venue  freq
# 0            Supermarket  0.11
# 1                 Bakery  0.11
# 2  Portuguese Restaurant  0.06
# 3            Music Venue  0.06
# 4                Brewery  0.06
#
#
# ----First Canadian Place, Underground city----
#          venue  freq
# 0  Coffee Shop  0.12
# 1         Café  0.08
# 2        Hotel  0.06
# 3   Restaurant  0.05
# 4   Steakhouse  0.04
#
#
# ----Forest Hill North, Forest Hill West----
#               venue  freq
# 0              Park   0.2
# 1             Trail   0.2
# 2  Sushi Restaurant   0.2
# 3          Bus Line   0.2
# 4     Jewelry Store   0.2
#
#
# ----Harbord, University of Toronto----
#          venue  freq
# 0         Café  0.12
# 1    Bookstore  0.06
# 2  Coffee Shop  0.06
# 3          Bar  0.06
# 4       Bakery  0.06
#
#
# ----Harbourfront East, Toronto Islands, Union Station----
#          venue  freq
# 0  Coffee Shop  0.14
# 1        Hotel  0.05
# 2     Aquarium  0.04
# 3         Café  0.04
# 4  Pizza Place  0.04
#
#
# ----Harbourfront, Regent Park----
#                 venue  freq
# 0         Coffee Shop  0.18
# 1                Park  0.08
# 2              Bakery  0.08
# 3                Café  0.06
# 4  Mexican Restaurant  0.04
#
#
# ----High Park, The Junction South----
#                 venue  freq
# 0  Mexican Restaurant  0.09
# 1                Café  0.09
# 2                 Bar  0.09
# 3     Thai Restaurant  0.04
# 4         Flea Market  0.04
#
#
# ----Lawrence Park----
#                 venue  freq
# 0                Park  0.25
# 1  Dim Sum Restaurant  0.25
# 2         Swim School  0.25
# 3            Bus Line  0.25
# 4   Accessories Store  0.00
#
#
# ----Little Portugal, Trinity----
#          venue  freq
# 0          Bar  0.12
# 1         Café  0.06
# 2   Restaurant  0.05
# 3  Coffee Shop  0.05
# 4       Bakery  0.03
#
#
# ----Moore Park, Summerhill East----
#                venue  freq
# 0         Playground  0.33
# 1                Gym  0.33
# 2        Summer Camp  0.33
# 3  Accessories Store  0.00
# 4        Music Venue  0.00
#
#
# ----North Toronto West----
#                      venue  freq
# 0      Sporting Goods Shop  0.10
# 1           Clothing Store  0.10
# 2              Coffee Shop  0.10
# 3  Health & Beauty Service  0.05
# 4       Mexican Restaurant  0.05
#
#
# ----Parkdale, Roncesvalles----
#           venue  freq
# 0   Coffee Shop  0.14
# 1     Gift Shop  0.14
# 2     Piano Bar  0.07
# 3       Dog Run  0.07
# 4  Burger Joint  0.07
#
#
# ----Rosedale----
#                venue  freq
# 0               Park  0.50
# 1         Playground  0.25
# 2              Trail  0.25
# 3  Accessories Store  0.00
# 4        Music Venue  0.00
#
#
# ----Roselawn----
#                venue  freq
# 0       Home Service   0.5
# 1             Garden   0.5
# 2  Accessories Store   0.0
# 3       Neighborhood   0.0
# 4        Men's Store   0.0
#
#
# ----Runnymede, Swansea----
#                 venue  freq
# 0         Pizza Place  0.07
# 1                Café  0.07
# 2         Coffee Shop  0.07
# 3  Italian Restaurant  0.05
# 4           Bookstore  0.05
#
#
# ----Ryerson, Garden District----
#             venue  freq
# 0     Coffee Shop  0.09
# 1  Clothing Store  0.07
# 2  Cosmetics Shop  0.04
# 3            Café  0.04
# 4             Bar  0.03
#
#
# ----St. James Town----
#             venue  freq
# 0     Coffee Shop  0.07
# 1            Café  0.06
# 2      Restaurant  0.05
# 3  Clothing Store  0.04
# 4           Hotel  0.04
#
#
# ----Stn A PO Boxes 25 The Esplanade----
#           venue  freq
# 0   Coffee Shop  0.10
# 1          Café  0.04
# 2    Restaurant  0.03
# 3      Beer Bar  0.03
# 4  Cocktail Bar  0.03
#
#
# ----Studio District----
#                 venue  freq
# 0                Café  0.10
# 1         Coffee Shop  0.08
# 2  Italian Restaurant  0.05
# 3           Gastropub  0.05
# 4              Bakery  0.05
#
#
# ----The Annex, North Midtown, Yorkville----
#             venue  freq
# 0     Coffee Shop  0.12
# 1  Sandwich Place  0.12
# 2            Café  0.12
# 3     Pizza Place  0.08
# 4  History Museum  0.04
#
#
# ----The Beaches----
#           venue  freq
# 0  Neighborhood   0.2
# 1   Coffee Shop   0.2
# 2           Pub   0.2
# 3  Dance Studio   0.2
# 4   Music Venue   0.2
#
#
# ----The Beaches West, India Bazaar----
#               venue  freq
# 0    Sandwich Place  0.10
# 1        Board Shop  0.05
# 2  Sushi Restaurant  0.05
# 3         Pet Store  0.05
# 4              Park  0.05
#
#
# ----The Danforth West, Riverdale----
#                 venue  freq
# 0    Greek Restaurant  0.24
# 1         Coffee Shop  0.10
# 2      Ice Cream Shop  0.07
# 3  Italian Restaurant  0.05
# 4           Bookstore  0.05

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = Toronto_grouped['Neighbourhood']

for ind in np.arange(Toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#                                         Neighbourhood 1st Most Common Venue  \
# 0                            Adelaide, King, Richmond           Coffee Shop
# 1                                         Berczy Park           Coffee Shop
# 2        Brockton, Exhibition Place, Parkdale Village           Coffee Shop
# 3    Business reply mail Processing Centre969 Eastern            Comic Shop
# 4   CN Tower, Bathurst Quay, Island airport, Harbo...        Airport Lounge
# 5                         Cabbagetown, St. James Town           Coffee Shop
# 6                                  Central Bay Street           Coffee Shop
# 7           Chinatown, Grange Park, Kensington Market                  Café
# 8                                            Christie         Grocery Store
# 9                                Church and Wellesley   Japanese Restaurant
# 10                     Commerce Court, Victoria Hotel           Coffee Shop
# 11                                         Davisville          Dessert Shop
# 12                                   Davisville North        Breakfast Spot
# 13  Deer Park, Forest Hill SE, Rathnelly, South Hi...           Coffee Shop
# 14           Design Exchange, Toronto Dominion Centre           Coffee Shop
# 15                       Dovercourt Village, Dufferin           Supermarket
# 16             First Canadian Place, Underground city           Coffee Shop
# 17                Forest Hill North, Forest Hill West              Bus Line
# 18                     Harbord, University of Toronto                  Café
# 19  Harbourfront East, Toronto Islands, Union Station           Coffee Shop
# 20                          Harbourfront, Regent Park           Coffee Shop
# 21                      High Park, The Junction South                  Café
# 22                                      Lawrence Park              Bus Line
# 23                           Little Portugal, Trinity                   Bar
# 24                        Moore Park, Summerhill East                   Gym
# 25                                 North Toronto West           Coffee Shop
# 26                             Parkdale, Roncesvalles           Coffee Shop
# 27                                           Rosedale                  Park
# 28                                           Roselawn                Garden
# 29                                 Runnymede, Swansea           Coffee Shop
# 30                           Ryerson, Garden District           Coffee Shop
# 31                                     St. James Town           Coffee Shop
# 32                    Stn A PO Boxes 25 The Esplanade           Coffee Shop
# 33                                    Studio District                  Café
# 34                The Annex, North Midtown, Yorkville                  Café
# 35                                        The Beaches           Music Venue
# 36                     The Beaches West, India Bazaar        Sandwich Place
# 37                       The Danforth West, Riverdale      Greek Restaurant
#
#             2nd Most Common Venue 3rd Most Common Venue  \
# 0                            Café            Steakhouse
# 1                    Cocktail Bar            Steakhouse
# 2                            Café        Breakfast Spot
# 3                         Butcher            Skate Park
# 4                 Airport Service      Airport Terminal
# 5                      Restaurant                  Café
# 6                            Café    Italian Restaurant
# 7   Vegetarian / Vegan Restaurant                   Bar
# 8                            Café                  Park
# 9                     Coffee Shop      Sushi Restaurant
# 10                          Hotel                  Café
# 11                 Sandwich Place      Sushi Restaurant
# 12                 Clothing Store          Burger Joint
# 13                            Pub   Fried Chicken Joint
# 14                          Hotel                  Café
# 15                         Bakery              Pharmacy
# 16                           Café                 Hotel
# 17                  Jewelry Store      Sushi Restaurant
# 18                         Bakery             Bookstore
# 19                          Hotel           Pizza Place
# 20                         Bakery                  Park
# 21                            Bar    Mexican Restaurant
# 22                           Park           Swim School
# 23                           Café            Restaurant
# 24                     Playground           Summer Camp
# 25                 Clothing Store   Sporting Goods Shop
# 26                      Gift Shop      Cuban Restaurant
# 27                     Playground                 Trail
# 28                   Home Service           Yoga Studio
# 29                           Café           Pizza Place
# 30                 Clothing Store        Cosmetics Shop
# 31                           Café            Restaurant
# 32                           Café              Beer Bar
# 33                    Coffee Shop    Italian Restaurant
# 34                    Coffee Shop        Sandwich Place
# 35                   Dance Studio          Neighborhood
# 36                      Pet Store            Steakhouse
# 37                    Coffee Shop        Ice Cream Shop
#
#     4th Most Common Venue      5th Most Common Venue  6th Most Common Venue  \
# 0                     Gym            Thai Restaurant    American Restaurant
# 1             Cheese Shop                       Café             Restaurant
# 2           Grocery Store         Italian Restaurant  Performing Arts Venue
# 3                     Spa             Farmers Market     Light Rail Station
# 4           Boat or Ferry                    Airport     Airport Food Court
# 5             Pizza Place         Chinese Restaurant                 Bakery
# 6         Bubble Tea Shop        Japanese Restaurant         Sandwich Place
# 7      Chinese Restaurant         Mexican Restaurant  Vietnamese Restaurant
# 8       Convenience Store                 Baby Store     Italian Restaurant
# 9                 Gay Bar               Burger Joint             Restaurant
# 10             Restaurant        American Restaurant             Steakhouse
# 11            Coffee Shop                 Restaurant     Italian Restaurant
# 12      Food & Drink Shop                      Hotel         Sandwich Place
# 13            Supermarket                 Bagel Shop             Sports Bar
# 14    American Restaurant                        Gym              Gastropub
# 15  Portuguese Restaurant                Music Venue         Discount Store
# 16             Restaurant                 Steakhouse                    Gym
# 17                  Trail                       Park            Event Space
# 18             Restaurant                Coffee Shop                    Bar
# 19               Aquarium                       Café                Brewery
# 20                   Café                        Pub         Breakfast Spot
# 21          Grocery Store  Cajun / Creole Restaurant     Italian Restaurant
# 22     Dim Sum Restaurant                      Diner     Falafel Restaurant
# 23            Coffee Shop               Cocktail Bar  Vietnamese Restaurant
# 24            Yoga Studio                      Diner     Falafel Restaurant
# 25                   Park                 Shoe Store         Sandwich Place
# 26         Breakfast Spot              Movie Theater                Dog Run
# 27            Yoga Studio         Dim Sum Restaurant            Event Space
# 28     Falafel Restaurant                Event Space   Ethiopian Restaurant
# 29     Italian Restaurant                  Bookstore       Sushi Restaurant
# 30                   Café        Japanese Restaurant                    Bar
# 31         Clothing Store                      Hotel              Gastropub
# 32             Restaurant         Seafood Restaurant           Cocktail Bar
# 33                 Bakery                  Gastropub    American Restaurant
# 34            Pizza Place                       Park              BBQ Joint
# 35                    Pub                Coffee Shop   Ethiopian Restaurant
# 36      Food & Drink Shop           Sushi Restaurant         Ice Cream Shop
# 37              Bookstore         Italian Restaurant         Cosmetics Shop
#
#    7th Most Common Venue          8th Most Common Venue  \
# 0                    Bar                     Restaurant
# 1     Seafood Restaurant                       Beer Bar
# 2              Pet Store                         Office
# 3   Fast Food Restaurant                        Brewery
# 4           Airport Gate                       Boutique
# 5      Convenience Store             Italian Restaurant
# 6           Burger Joint                 Ice Cream Shop
# 7                 Bakery            Dumpling Restaurant
# 8     Athletics & Sports                     Restaurant
# 9                    Pub                      Gastropub
# 10    Italian Restaurant                            Gym
# 11                  Café                    Pizza Place
# 12           Pizza Place                           Park
# 13   American Restaurant               Sushi Restaurant
# 14         Deli / Bodega             Italian Restaurant
# 15                  Café      Middle Eastern Restaurant
# 16             Gastropub                  Deli / Bodega
# 17  Ethiopian Restaurant              Electronics Store
# 18   Japanese Restaurant                      Nightclub
# 19        Scenic Lookout                     Sports Bar
# 20    Mexican Restaurant                        Theater
# 21   Fried Chicken Joint         Furniture / Home Store
# 22           Event Space           Ethiopian Restaurant
# 23     French Restaurant  Vegetarian / Vegan Restaurant
# 24           Event Space           Ethiopian Restaurant
# 25    Salon / Barbershop                           Café
# 26            Restaurant                   Dessert Shop
# 27  Ethiopian Restaurant              Electronics Store
# 28     Electronics Store    Eastern European Restaurant
# 29                   Bar              Fish & Chips Shop
# 30            Restaurant               Ramen Restaurant
# 31        Cosmetics Shop            Japanese Restaurant
# 32                 Hotel                 Cosmetics Shop
# 33           Fish Market                      Juice Bar
# 34     Indian Restaurant              French Restaurant
# 35     Electronics Store    Eastern European Restaurant
# 36                   Pub              Fish & Chips Shop
# 37               Brewery                Bubble Tea Shop
#
#           9th Most Common Venue       10th Most Common Venue
# 0                         Hotel          Japanese Restaurant
# 1                        Bakery               Farmers Market
# 2                           Gym                    Nightclub
# 3                 Burrito Place                   Restaurant
# 4               Harbor / Marina                        Plane
# 5             Indian Restaurant                          Pub
# 6                           Bar                          Spa
# 7                   Coffee Shop            Hotpot Restaurant
# 8                     Nightclub                  Coffee Shop
# 9                          Café              Bubble Tea Shop
# 10           Seafood Restaurant                Deli / Bodega
# 11           Seafood Restaurant             Toy / Game Store
# 12  Eastern European Restaurant            Electronics Store
# 13                  Pizza Place            Convenience Store
# 14                   Restaurant                   Sports Bar
# 15                      Brewery                 Liquor Store
# 16                          Bar          American Restaurant
# 17  Eastern European Restaurant                        Diner
# 18             Sushi Restaurant                Poutine Place
# 19           Italian Restaurant             Sushi Restaurant
# 20                          Spa                         Bank
# 21          Arts & Crafts Store                        Diner
# 22            Electronics Store  Eastern European Restaurant
# 23                       Bakery             Asian Restaurant
# 24            Electronics Store  Eastern European Restaurant
# 25           Chinese Restaurant                 Dessert Shop
# 26                          Bar                 Burger Joint
# 27  Eastern European Restaurant          Dumpling Restaurant
# 28          Dumpling Restaurant                   Donut Shop
# 29          Indie Movie Theater                     Pharmacy
# 30                    Bookstore                        Diner
# 31           Italian Restaurant                         Park
# 32                       Bakery                     Creperie
# 33      New American Restaurant                    Bookstore
# 34                          Pub            Jewish Restaurant
# 35          Dumpling Restaurant           Dim Sum Restaurant
# 36                        Hotel                Burrito Place
# 37                         Café         Caribbean Restaurant

# %% [markdown]
# ## Run k-means to cluster the neighborhood

# %%
# set number of clusters
kclusters = 8

Toronto_grouped_clustering = Toronto_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Toronto_grouped_clustering)

# %%
Toronto_merged = borough_Toronto_data

# add clustering labels
Toronto_merged['Cluster Labels'] = kmeans.labels_

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
Toronto_merged = Toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')

Toronto_merged.head() # check the last columns!
# Out:
#   Postcode          Borough                   Neighbourhood   Latitude  \
# 0      M4E     East Toronto                     The Beaches  43.676357
# 1      M4K     East Toronto    The Danforth West, Riverdale  43.679557
# 2      M4L     East Toronto  The Beaches West, India Bazaar  43.668999
# 3      M4M     East Toronto                 Studio District  43.659526
# 4      M4N  Central Toronto                   Lawrence Park  43.728020
#
#    Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.293031               0           Music Venue          Dance Studio
# 1 -79.352188               0      Greek Restaurant           Coffee Shop
# 2 -79.315572               0        Sandwich Place             Pet Store
# 3 -79.340923               0                  Café           Coffee Shop
# 4 -79.388790               4              Bus Line                  Park
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0          Neighborhood                   Pub           Coffee Shop
# 1        Ice Cream Shop             Bookstore    Italian Restaurant
# 2            Steakhouse     Food & Drink Shop      Sushi Restaurant
# 3    Italian Restaurant                Bakery             Gastropub
# 4           Swim School    Dim Sum Restaurant                 Diner
#
#   6th Most Common Venue 7th Most Common Venue        8th Most Common Venue  \
# 0  Ethiopian Restaurant     Electronics Store  Eastern European Restaurant
# 1        Cosmetics Shop               Brewery              Bubble Tea Shop
# 2        Ice Cream Shop                   Pub            Fish & Chips Shop
# 3   American Restaurant           Fish Market                    Juice Bar
# 4    Falafel Restaurant           Event Space         Ethiopian Restaurant
#
#      9th Most Common Venue       10th Most Common Venue
# 0      Dumpling Restaurant           Dim Sum Restaurant
# 1                     Café         Caribbean Restaurant
# 2                    Hotel                Burrito Place
# 3  New American Restaurant                    Bookstore
# 4        Electronics Store  Eastern European Restaurant

# %%
print(len(Toronto_merged),len(Toronto_grouped))dd
# Out:
# 38 38

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Toronto_merged['Latitude'], Toronto_merged['Longitude'], Toronto_merged['Neighbourhood'], Toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now, let's define a query to search for Asian food that is within 5000 metres from the Toronto center.

# %%
radius = 10000
LIMIT = 500 # limit of number of venues returned by Foursquare API
print(search_query + ' .... OK!')
# Out:
# restaurant .... OK!

# %%
search_query = 'restaurant'
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5bba29d86a6071462c7dd0fd'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d123941735',
#       'name': 'Wine Bar',
#       'pluralName': 'Wine Bars',
#       'primary': True,
#       'shortName': 'Wine Bar'}],
#     'hasPerk': False,
#     'id': '4ad4c05cf964a520dff520e3',
#     'location': {'address': 'CN Tower',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': '301 Front St. W',
#      'distance': 1271,
#      'formattedAddress': ['CN Tower (301 Front St. W)',
#       'Toronto ON M5V 2T6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.642537317144566,
#        'lng': -79.38704201569328}],
#      'lat': 43.642537317144566,
#      'lng': -79.38704201569328,
#      'postalCode': 'M5V 2T6',
#      'state': 'ON'},
#     'name': '360 Restaurant',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'primary': True,
#       'shortName': 'American'}],
#     'hasPerk': False,
#     'id': '4ad4c05ff964a52048f720e3',
#     'location': {'address': '110 Chestnut Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 145,
#      'formattedAddress': ['110 Chestnut Street',
#       'Toronto ON M5G 1R3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65488413420439,
#        'lng': -79.38593077371578}],
#      'lat': 43.65488413420439,
#      'lng': -79.38593077371578,
#      'postalCode': 'M5G 1R3',
#      'state': 'ON'},
#     'name': 'Hemispheres Restaurant & Bistro',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4baa4b39f964a520ec5b3ae3',
#     'location': {'address': '181 Bay St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'in Brookfield Place',
#      'distance': 1077,
#      'formattedAddress': ['181 Bay St. (in Brookfield Place)',
#       'Toronto ON M5J 2T3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64723237089591,
#        'lng': -79.37759119081164}],
#      'lat': 43.64723237089591,
#      'lng': -79.37759119081164,
#      'postalCode': 'M5J 2T3',
#      'state': 'ON'},
#     'name': 'Marché Restaurant',
#     'referralId': 'v-1538927065',
#     'venuePage': {'id': '59869170'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'primary': True,
#       'shortName': 'Dim Sum'}],
#     'hasPerk': False,
#     'id': '4ad4c060f964a5207ff720e3',
#     'location': {'address': '323 Spadina Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': "at D'Arcy St.",
#      'distance': 922,
#      'formattedAddress': ["323 Spadina Ave. (at D'Arcy St.)",
#       'Toronto ON M5T 2E9',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65431754076345,
#        'lng': -79.39864998374682}],
#      'lat': 43.65431754076345,
#      'lng': -79.39864998374682,
#      'postalCode': 'M5T 2E9',
#      'state': 'ON'},
#     'name': 'Rol San Restaurant 龍笙棧',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4ad4c05cf964a52006f620e3',
#     'location': {'address': '37 King Street East',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Le Meridien King Edward Hotel',
#      'distance': 1011,
#      'formattedAddress': ['37 King Street East (at Le Meridien King Edward Hotel)',
#       'Toronto ON M5C 1E9',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64929834396347,
#        'lng': -79.37643067251867}],
#      'lat': 43.64929834396347,
#      'lng': -79.37643067251867,
#      'postalCode': 'M5C 1E9',
#      'state': 'ON'},
#     'name': "Victoria's Restaurant",
#     'referralId': 'v-1538927065',
#     'venuePage': {'id': '498556908'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4ae29812f964a520288f21e3',
#     'location': {'address': '309 Spadina Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': "btwn Dundas St. W & D'Arcy St.",
#      'distance': 896,
#      'formattedAddress': ["309 Spadina Ave. (btwn Dundas St. W & D'Arcy St.)",
#       'Toronto ON M5T 2E6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65386562507761,
#        'lng': -79.39833353339202}],
#      'lat': 43.65386562507761,
#      'lng': -79.39833353339202,
#      'postalCode': 'M5T 2E6',
#      'state': 'ON'},
#     'name': 'Swatow Restaurant 汕頭小食家',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d1941735',
#       'name': 'Noodle House',
#       'pluralName': 'Noodle Houses',
#       'primary': True,
#       'shortName': 'Noodles'}],
#     'hasPerk': False,
#     'id': '4b266f05f964a520657b24e3',
#     'location': {'address': '266 Spadina Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Willison Sq',
#      'distance': 892,
#      'formattedAddress': ['266 Spadina Ave (at Willison Sq)',
#       'Toronto ON M5T 2E4',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6522783893466,
#        'lng': -79.39803917534071}],
#      'lat': 43.6522783893466,
#      'lng': -79.39803917534071,
#      'postalCode': 'M5T 2E4',
#      'state': 'ON'},
#     'name': 'Goldstone Noodle Restaurant 金石',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'primary': True,
#       'shortName': 'Dim Sum'}],
#     'hasPerk': False,
#     'id': '4b072e9df964a52009f922e3',
#     'location': {'address': '280 Spadina Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Dundas St. W.',
#      'distance': 892,
#      'formattedAddress': ['280 Spadina Ave. (at Dundas St. W.)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65278331265585,
#        'lng': -79.39817372355205}],
#      'lat': 43.65278331265585,
#      'lng': -79.39817372355205,
#      'state': 'ON'},
#     'name': 'Sky Dragon Chinese Restaurant 龍翔酒樓',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'primary': True,
#       'shortName': 'American'}],
#     'hasPerk': False,
#     'id': '4ada5d5bf964a520e92121e3',
#     'location': {'address': '35 Church St',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Front St E',
#      'distance': 1233,
#      'formattedAddress': ['35 Church St (at Front St E)',
#       'Toronto ON M5E 1T3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.648682887543444,
#        'lng': -79.37374087760644}],
#      'lat': 43.648682887543444,
#      'lng': -79.37374087760644,
#      'postalCode': 'M5E 1T3',
#      'state': 'ON'},
#     'name': 'The Hot House Restaurant & Bar',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4b223f5af964a520ba4424e3',
#     'location': {'address': '225 Frnt St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1039,
#      'formattedAddress': ['225 Frnt St W', 'Toronto ON M5V 2X3', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.644749195919346,
#        'lng': -79.38511295085902}],
#      'lat': 43.644749195919346,
#      'lng': -79.38511295085902,
#      'neighborhood': 'Entertainment District',
#      'postalCode': 'M5V 2X3',
#      'state': 'ON'},
#     'name': 'Azure Restaurant & Bar',
#     'referralId': 'v-1538927065',
#     'venuePage': {'id': '136175835'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'primary': True,
#       'shortName': 'Event Space'}],
#     'hasPerk': False,
#     'id': '4ad4c05cf964a520cef520e3',
#     'location': {'address': '100 Cumberland Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Bellair St',
#      'distance': 1849,
#      'formattedAddress': ['100 Cumberland Street (Bellair St)',
#       'Toronto ON M5R 1A6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.67034226367314,
#        'lng': -79.39104050451753}],
#      'lat': 43.67034226367314,
#      'lng': -79.39104050451753,
#      'postalCode': 'M5R 1A6',
#      'state': 'ON'},
#     'name': 'Sassafraz | Cafe | Restaurant | Private Events',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4aef8854f964a5201cd921e3',
#     'location': {'address': '287 King St. W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at John St.',
#      'distance': 857,
#      'formattedAddress': ['287 King St. W (at John St.)',
#       'Toronto ON M5V 1J5',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646462521503445,
#        'lng': -79.38964414801342}],
#      'lat': 43.646462521503445,
#      'lng': -79.38964414801342,
#      'postalCode': 'M5V 1J5',
#      'state': 'ON'},
#     'name': 'Aroma Fine Indian Restaurant',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '50ca02c0245f2d4aa8c2b313',
#     'location': {'address': '145 Richmond Street West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Hilton Toronto',
#      'distance': 458,
#      'formattedAddress': ['145 Richmond Street West (Hilton Toronto)',
#       'Toronto ON M5H 2L2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650009987649646,
#        'lng': -79.38560774268629}],
#      'lat': 43.650009987649646,
#      'lng': -79.38560774268629,
#      'postalCode': 'M5H 2L2',
#      'state': 'ON'},
#     'name': 'Tundra Restaurant',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'primary': True,
#       'shortName': 'Korean'}],
#     'hasPerk': False,
#     'id': '4ba2d00cf964a5203e1b38e3',
#     'location': {'address': '8 St Andrew St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Spadina Ave.',
#      'distance': 972,
#      'formattedAddress': ['8 St Andrew St. (at Spadina Ave.)',
#       'Toronto ON M5T 1K6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654306552286656,
#        'lng': -79.3992765578534}],
#      'lat': 43.654306552286656,
#      'lng': -79.3992765578534,
#      'postalCode': 'M5T 1K6',
#      'state': 'ON'},
#     'name': 'Ka Chi Korean Restaurant',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4b074bb1f964a52077fb22e3',
#     'location': {'address': '353 Spadina Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 953,
#      'formattedAddress': ['353 Spadina Ave.', 'Toronto ON M5T 2G3', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65533674412141,
#        'lng': -79.39889716243826}],
#      'lat': 43.65533674412141,
#      'lng': -79.39889716243826,
#      'postalCode': 'M5T 2G3',
#      'state': 'ON'},
#     'name': 'New Sky Restaurant 小沙田食家',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'primary': True,
#       'shortName': 'New American'}],
#     'hasPerk': False,
#     'id': '4b02a076f964a520234922e3',
#     'location': {'address': '116 Yorkville Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Hazelton Ave.',
#      'distance': 1937,
#      'formattedAddress': ['116 Yorkville Ave (at Hazelton Ave.)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.670809368275535,
#        'lng': -79.39327240013003}],
#      'lat': 43.670809368275535,
#      'lng': -79.39327240013003,
#      'state': 'ON'},
#     'name': 'ONE Restaurant/Lounge',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4b295e10f964a520ba9d24e3',
#     'location': {'address': '14 Queen St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 581,
#      'formattedAddress': ['14 Queen St W', 'Toronto ON M5H 3X4', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652614361741726,
#        'lng': -79.38023131683906}],
#      'lat': 43.652614361741726,
#      'lng': -79.38023131683906,
#      'postalCode': 'M5H 3X4',
#      'state': 'ON'},
#     'name': 'Richtree Natural Market Restaurants',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4ad4c05cf964a520cdf520e3',
#     'location': {'address': '563 Bloor St West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Bathurst St',
#      'distance': 2284,
#      'formattedAddress': ['563 Bloor St West (Bathurst St)',
#       'Toronto ON M5S 1Y6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.665179618013326,
#        'lng': -79.41096552569321}],
#      'lat': 43.665179618013326,
#      'lng': -79.41096552569321,
#      'postalCode': 'M5S 1Y6',
#      'state': 'ON'},
#     'name': 'Insomnia Restaurant and Lounge',
#     'referralId': 'v-1538927065',
#     'venuePage': {'id': '51631703'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'primary': True,
#       'shortName': 'Diner'}],
#     'hasPerk': False,
#     'id': '4b22e814f964a520175024e3',
#     'location': {'address': '1132 Dundas St. W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Ossington Ave.',
#      'distance': 2719,
#      'formattedAddress': ['1132 Dundas St. W (at Ossington Ave.)',
#       'Toronto ON M6J 1X2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64943515996231,
#        'lng': -79.42039021958406}],
#      'lat': 43.64943515996231,
#      'lng': -79.42039021958406,
#      'postalCode': 'M6J 1X2',
#      'state': 'ON'},
#     'name': 'The Lakeview Restaurant',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'primary': True,
#       'shortName': 'New American'}],
#     'hasPerk': False,
#     'id': '4cc3a79bbde8f04d0ddba64b',
#     'location': {'address': '293 Palmerston Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at College St.',
#      'distance': 1841,
#      'formattedAddress': ['293 Palmerston Ave. (at College St.)',
#       'Toronto ON M6J 2J3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655765,
#        'lng': -79.409929}],
#      'lat': 43.655765,
#      'lng': -79.409929,
#      'postalCode': 'M6J 2J3',
#      'state': 'ON'},
#     'name': 'Woodlot Restaurant & Bakery',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'primary': True,
#       'shortName': 'Japanese'}],
#     'hasPerk': False,
#     'id': '4b6a1058f964a52028c52be3',
#     'location': {'address': '31 Baldwin St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'McCaul St.',
#      'distance': 549,
#      'formattedAddress': ['31 Baldwin St. (McCaul St.)',
#       'Toronto ON M5T 1L1',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656078916507376,
#        'lng': -79.39337113868667}],
#      'lat': 43.656078916507376,
#      'lng': -79.39337113868667,
#      'postalCode': 'M5T 1L1',
#      'state': 'ON'},
#     'name': 'Konnichiwa Japanese Restaurant こんにちわ',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4ad4c05df964a5203ff620e3',
#     'location': {'address': '30 Mercer Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at John St',
#      'distance': 979,
#      'formattedAddress': ['30 Mercer Street (at John St)',
#       'Toronto ON M5V 1H3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64563436248102,
#        'lng': -79.39112538566908}],
#      'lat': 43.64563436248102,
#      'lng': -79.39112538566908,
#      'postalCode': 'M5V 1H3',
#      'state': 'ON'},
#     'name': 'Victor Restaurant & Bar',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4b7b22a4f964a52085532fe3',
#     'location': {'address': '530 Dundas St. W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Spadina Ave.',
#      'distance': 946,
#      'formattedAddress': ['530 Dundas St. W (at Spadina Ave.)',
#       'Toronto ON M5T 1H3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65272353176442,
#        'lng': -79.39883856942056}],
#      'lat': 43.65272353176442,
#      'lng': -79.39883856942056,
#      'postalCode': 'M5T 1H3',
#      'state': 'ON'},
#     'name': 'Noble Chinese Restaurant',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4d06c1ccc2e53704428cc567',
#     'location': {'address': '476 Dundas St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Huron',
#      'distance': 767,
#      'formattedAddress': ['476 Dundas St. (Huron)', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6531846832903,
#        'lng': -79.3966766276528}],
#      'lat': 43.6531846832903,
#      'lng': -79.3966766276528,
#      'state': 'ON'},
#     'name': 'North-East Chinese Restaurant 華北美食',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'primary': True,
#       'shortName': 'Breakfast'}],
#     'hasPerk': False,
#     'id': '4bd47e6fcfa7b7139f2924da',
#     'location': {'address': '389 Church St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Carlton St.',
#      'distance': 1052,
#      'formattedAddress': ['389 Church St. (at Carlton St.)',
#       'Toronto ON M5B',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.661500159065305,
#        'lng': -79.3793192447337}],
#      'lat': 43.661500159065305,
#      'lng': -79.3793192447337,
#      'postalCode': 'M5B',
#      'state': 'ON'},
#     'name': 'Studio Restaurant',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c0941735',
#       'name': 'Mediterranean Restaurant',
#       'pluralName': 'Mediterranean Restaurants',
#       'primary': True,
#       'shortName': 'Mediterranean'}],
#     'hasPerk': False,
#     'id': '5792bb19498e1e1d0b52f008',
#     'location': {'address': '134 Peter Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 783,
#      'formattedAddress': ['134 Peter Street', 'Toronto ON M5V 2H2', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64855585967538,
#        'lng': -79.39343248995296}],
#      'lat': 43.64855585967538,
#      'lng': -79.39343248995296,
#      'postalCode': 'M5V 2H2',
#      'state': 'ON'},
#     'name': "Ricarda's Restaurant",
#     'referralId': 'v-1538927065',
#     'venuePage': {'id': '357301892'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'primary': True,
#       'shortName': 'Diner'}],
#     'hasPerk': False,
#     'id': '4ad7929cf964a520500c21e3',
#     'location': {'address': '249 Victoria Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'btwn Dundas St E and Shuter St',
#      'distance': 671,
#      'formattedAddress': ['249 Victoria Street (btwn Dundas St E and Shuter St)',
#       'Toronto ON M5B 1T8',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65564091455335,
#        'lng': -79.37919882575557}],
#      'lat': 43.65564091455335,
#      'lng': -79.37919882575557,
#      'postalCode': 'M5B 1T8',
#      'state': 'ON'},
#     'name': 'The Senator Restaurant',
#     'referralId': 'v-1538927065',
#     'venuePage': {'id': '55585058'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10c941735',
#       'name': 'French Restaurant',
#       'pluralName': 'French Restaurants',
#       'primary': True,
#       'shortName': 'French'}],
#     'hasPerk': False,
#     'id': '4ada6d8df964a520832221e3',
#     'location': {'address': '72 Ossington Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Queen St. W',
#      'distance': 2755,
#      'formattedAddress': ['72 Ossington Ave. (Queen St. W)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64585979013257,
#        'lng': -79.41953208988866}],
#      'lat': 43.64585979013257,
#      'lng': -79.41953208988866,
#      'state': 'ON'},
#     'name': 'Union Restaurant',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'primary': True,
#       'shortName': 'Breakfast'}],
#     'hasPerk': False,
#     'id': '4bce1ec0cc8cd13a9ac8c3cf',
#     'location': {'address': '2A Kensington Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Dundas St. W',
#      'distance': 1035,
#      'formattedAddress': ['2A Kensington Ave. (Dundas St. W)',
#       'Toronto ON M5T 2J7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65280330843737,
#        'lng': -79.39995806711424}],
#      'lat': 43.65280330843737,
#      'lng': -79.39995806711424,
#      'postalCode': 'M5T 2J7',
#      'state': 'ON'},
#     'name': 'Kensington Cornerstone Restaurant',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4b2027b5f964a520f82d24e3',
#     'location': {'address': '195 Dundas St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at University Ave',
#      'distance': 107,
#      'formattedAddress': ['195 Dundas St W (at University Ave)',
#       'Toronto ON M5G 1C7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65492521335936,
#        'lng': -79.38708916106386}],
#      'lat': 43.65492521335936,
#      'lng': -79.38708916106386,
#      'postalCode': 'M5G 1C7',
#      'state': 'ON'},
#     'name': 'Hong Shing Chinese Restaurant',
#     'referralId': 'v-1538927065',
#     'venuePage': {'id': '60327598'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4ad4c05ff964a5200bf720e3',
#     'location': {'address': '346-348 Spadina Avenue',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 960,
#      'formattedAddress': ['346-348 Spadina Avenue',
#       'Toronto ON M5T 2G2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654219,
#        'lng': -79.399125}],
#      'lat': 43.654219,
#      'lng': -79.399125,
#      'postalCode': 'M5T 2G2',
#      'state': 'ON'},
#     'name': 'Bright Pearl Seafood Restaurant',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'primary': True,
#       'shortName': 'Breakfast'}],
#     'hasPerk': False,
#     'id': '4ae094a7f964a5208f8021e3',
#     'location': {'address': '70 Fraser Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Liberty St.',
#      'distance': 3489,
#      'formattedAddress': ['70 Fraser Ave. (at Liberty St.)',
#       'Toronto ON M6K 3C5',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6377753703417,
#        'lng': -79.42429737067897}],
#      'lat': 43.6377753703417,
#      'lng': -79.42429737067897,
#      'postalCode': 'M6K 3C5',
#      'state': 'ON'},
#     'name': 'SCHOOL Restaurant',
#     'referralId': 'v-1538927065',
#     'venuePage': {'id': '38118429'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'primary': True,
#       'shortName': 'Dim Sum'}],
#     'hasPerk': False,
#     'id': '4ddbe8697d8b771c0b09b885',
#     'location': {'address': '421 Dundas St. W, 3rd Floor',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 673,
#      'formattedAddress': ['421 Dundas St. W, 3rd Floor',
#       'Toronto ON M5T 1G6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653430070396446,
#        'lng': -79.39553945215319}],
#      'lat': 43.653430070396446,
#      'lng': -79.39553945215319,
#      'postalCode': 'M5T 1G6',
#      'state': 'ON'},
#     'name': 'Dim Sum King Seafood Restaurant',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'primary': True,
#       'shortName': 'Caribbean'}],
#     'hasPerk': False,
#     'id': '5b1c3098f96b2c002c5eb0c5',
#     'location': {'address': '405 Spadina Ave',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'College St',
#      'distance': 1019,
#      'formattedAddress': ['405 Spadina Ave (College St)',
#       'Toronto ON M5T 2G6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656794,
#        'lng': -79.399251}],
#      'lat': 43.656794,
#      'lng': -79.399251,
#      'postalCode': 'M5T 2G6',
#      'state': 'ON'},
#     'name': "Tasty's Caribbean Restaurant & Catering",
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'primary': True,
#       'shortName': 'Japanese'}],
#     'hasPerk': False,
#     'id': '5a62412b1108ba191da5ba06',
#     'location': {'address': '655 Bay Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': '( Bay st & Elm st)',
#      'distance': 468,
#      'formattedAddress': ['655 Bay Street (( Bay st & Elm st))',
#       'Toronto ON M5G 1Z4',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65749652942284,
#        'lng': -79.38404738903046}],
#      'lat': 43.65749652942284,
#      'lng': -79.38404738903046,
#      'postalCode': 'M5G 1Z4',
#      'state': 'ON'},
#     'name': 'KAKA All You Can Eat Japanese Restaurant (Downtown)',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '537e313d498e9e9e015f3018',
#     'location': {'address': '299 Adelaide St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Peter St',
#      'distance': 769,
#      'formattedAddress': ['299 Adelaide St W (Peter St)',
#       'Toronto ON M5V 1P7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64764401408166,
#        'lng': -79.3910688649793}],
#      'lat': 43.64764401408166,
#      'lng': -79.3910688649793,
#      'postalCode': 'M5V 1P7',
#      'state': 'ON'},
#     'name': 'Montecito Restaurant',
#     'referralId': 'v-1538927065',
#     'venuePage': {'id': '145052232'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11f941735',
#       'name': 'Nightclub',
#       'pluralName': 'Nightclubs',
#       'primary': True,
#       'shortName': 'Nightclub'}],
#     'hasPerk': False,
#     'id': '4ad4c05df964a52076f620e3',
#     'location': {'address': '430 College St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Bathurst St.',
#      'distance': 1630,
#      'formattedAddress': ['430 College St. (at Bathurst St.)',
#       'Toronto ON M5T 1T3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65667340500913,
#        'lng': -79.40710106606636}],
#      'lat': 43.65667340500913,
#      'lng': -79.40710106606636,
#      'postalCode': 'M5T 1T3',
#      'state': 'ON'},
#     'name': 'El Rancho Restaurant & Night Club',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'primary': True,
#       'shortName': 'Korean'}],
#     'hasPerk': False,
#     'id': '4b11b1f2f964a520778223e3',
#     'location': {'address': '628 Bloor Street West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 2481,
#      'formattedAddress': ['628 Bloor Street West', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.664497913032065,
#        'lng': -79.41436726023312}],
#      'lat': 43.664497913032065,
#      'lng': -79.41436726023312,
#      'state': 'ON'},
#     'name': 'Korean Village Restaurant',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4ad4c060f964a5208af720e3',
#     'location': {'address': '1 Blue Jays Way',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'inside the Renaissance Hotel',
#      'distance': 1397,
#      'formattedAddress': ['1 Blue Jays Way (inside the Renaissance Hotel)',
#       'Toronto ON M5V 1J4',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.641479256282814,
#        'lng': -79.38907384872437}],
#      'lat': 43.641479256282814,
#      'lng': -79.38907384872437,
#      'postalCode': 'M5V 1J4',
#      'state': 'ON'},
#     'name': 'Arriba Restaurant',
#     'referralId': 'v-1538927065',
#     'venuePage': {'id': '68079429'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'primary': True,
#       'shortName': 'Thai'}],
#     'hasPerk': False,
#     'id': '4ad4c05ff964a52018f720e3',
#     'location': {'address': '338 Jarvis St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'north of Carlton Street',
#      'distance': 1284,
#      'formattedAddress': ['338 Jarvis St. (north of Carlton Street)',
#       'Toronto ON M4Y 2G6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66277006654972,
#        'lng': -79.37689434011018}],
#      'lat': 43.66277006654972,
#      'lng': -79.37689434011018,
#      'postalCode': 'M4Y 2G6',
#      'state': 'ON'},
#     'name': 'Cottage Restaurant & Lounge',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'primary': True,
#       'shortName': 'American'}],
#     'hasPerk': False,
#     'id': '4bc3ad5e461576b0db037f32',
#     'location': {'address': 'Rogers Centre',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1383,
#      'formattedAddress': ['Rogers Centre', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.641635072211194,
#        'lng': -79.38936460164057}],
#      'lat': 43.641635072211194,
#      'lng': -79.38936460164057,
#      'state': 'ON'},
#     'name': 'Sightlines Restaurant',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'primary': True,
#       'shortName': 'Dim Sum'}],
#     'hasPerk': False,
#     'id': '4b2a674ef964a52074a824e3',
#     'location': {'address': '150 Dundas St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Elizabeth',
#      'distance': 217,
#      'formattedAddress': ['150 Dundas St W (at Elizabeth)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65538444237565,
#        'lng': -79.3853618106867}],
#      'lat': 43.65538444237565,
#      'lng': -79.3853618106867,
#      'state': 'ON'},
#     'name': 'New Treasure Restaurant',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4ae4b055f964a520229d21e3',
#     'location': {'address': '143 Dundas St. West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 221,
#      'formattedAddress': ['143 Dundas St. West', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65538110598594,
#        'lng': -79.38527010094231}],
#      'lat': 43.65538110598594,
#      'lng': -79.38527010094231,
#      'state': 'ON'},
#     'name': 'Kyoto House Japanese Restaurant',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '5a8b24b2018cbb6c4ca70dae',
#     'location': {'address': 'Yonge And Queen',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 628,
#      'formattedAddress': ['Yonge And Queen', 'Toronto ON M5G 2H6', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652887,
#        'lng': -79.379542}],
#      'lat': 43.652887,
#      'lng': -79.379542,
#      'postalCode': 'M5G 2H6',
#      'state': 'ON'},
#     'name': 'Hendricks Restaurant & Bar',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'primary': True,
#       'shortName': 'Korean'}],
#     'hasPerk': False,
#     'id': '4b19c8b7f964a52017e423e3',
#     'location': {'address': '661 Bloor Street West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Manning',
#      'distance': 2564,
#      'formattedAddress': ['661 Bloor Street West (Manning)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66418287914217,
#        'lng': -79.41574611551155}],
#      'lat': 43.66418287914217,
#      'lng': -79.41574611551155,
#      'state': 'ON'},
#     'name': 'Sunrise House Korean Restaurant 해뜨는집',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'primary': True,
#       'shortName': 'Deli / Bodega'}],
#     'hasPerk': False,
#     'id': '562922be498e2c6aad0e6091',
#     'location': {'address': '25 Lower Simcoe St',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Grand Trunk Cresc',
#      'distance': 1411,
#      'formattedAddress': ['25 Lower Simcoe St (Grand Trunk Cresc)',
#       'Toronto ON M5J 3A1',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64157991761808,
#        'lng': -79.38345644030795}],
#      'lat': 43.64157991761808,
#      'lng': -79.38345644030795,
#      'postalCode': 'M5J 3A1',
#      'state': 'ON'},
#     'name': 'Evviva Restaurant',
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4b4d3b51f964a520e4ce26e3',
#     'location': {'address': '90 Bloor St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Yonge St.',
#      'distance': 1858,
#      'formattedAddress': ['90 Bloor St. (Yonge St.)',
#       'Toronto ON M4W 1A7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.67057375344845,
#        'lng': -79.38485582052517}],
#      'lat': 43.67057375344845,
#      'lng': -79.38485582052517,
#      'postalCode': 'M4W 1A7',
#      'state': 'ON'},
#     'name': 'Matisse Restaurant And Bar',
#     'referralId': 'v-1538927065',
#     'venuePage': {'id': '83923512'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4ad8a5a7f964a5203c1321e3',
#     'location': {'address': '255 Queen St. W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Queen and University',
#      'distance': 430,
#      'formattedAddress': ['255 Queen St. W (Queen and University)',
#       'Toronto ON M5V 1Z4',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65031880877208,
#        'lng': -79.38899760320798}],
#      'lat': 43.65031880877208,
#      'lng': -79.38899760320798,
#      'postalCode': 'M5V 1Z4',
#      'state': 'ON'},
#     'name': 'Little India Restaurant',
#     'referralId': 'v-1538927065',
#     'venuePage': {'id': '57793907'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4c47d78c1ddec92817ca9e32',
#     'location': {'address': '566 Queen St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 1507,
#      'formattedAddress': ['566 Queen St W', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.647289322295066,
#        'lng': -79.40349333397708}],
#      'lat': 43.647289322295066,
#      'lng': -79.40349333397708,
#      'state': 'ON'},
#     'name': "Micheal's Restaurant and Deli",
#     'referralId': 'v-1538927065'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '52a7ae41498eed3af4d0a3fa',
#     'location': {'address': '126 Elizabeth St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Dundas St.',
#      'distance': 210,
#      'formattedAddress': ['126 Elizabeth St. (Dundas St.)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655281263429195,
#        'lng': -79.3853365267765}],
#      'lat': 43.655281263429195,
#      'lng': -79.3853365267765,
#      'state': 'ON'},
#     'name': 'Yueh Tung Chinese Restaurant',
#     'referralId': 'v-1538927065'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
print(dataframe.shape)
dataframe.head()
# Out:
# (50, 19)
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d123941735', 'name': 'W...    False
# 1  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 3  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...    False
# 4  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
#
#                          id     location.address location.cc location.city  \
# 0  4ad4c05cf964a520dff520e3             CN Tower          CA       Toronto
# 1  4ad4c05ff964a52048f720e3  110 Chestnut Street          CA       Toronto
# 2  4baa4b39f964a520ec5b3ae3          181 Bay St.          CA       Toronto
# 3  4ad4c060f964a5207ff720e3     323 Spadina Ave.          CA       Toronto
# 4  4ad4c05cf964a52006f620e3  37 King Street East          CA       Toronto
#
#   location.country              location.crossStreet  location.distance  \
# 0           Canada                   301 Front St. W               1271
# 1           Canada                               NaN                145
# 2           Canada               in Brookfield Place               1077
# 3           Canada                     at D'Arcy St.                922
# 4           Canada  at Le Meridien King Edward Hotel               1011
#
#                            location.formattedAddress  \
# 0  [CN Tower (301 Front St. W), Toronto ON M5V 2T...
# 1  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 2  [181 Bay St. (in Brookfield Place), Toronto ON...
# 3  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 4  [37 King Street East (at Le Meridien King Edwa...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.64253731714456...     43.642537
# 1  [{'label': 'display', 'lat': 43.65488413420439...     43.654884
# 2  [{'label': 'display', 'lat': 43.64723237089591...     43.647232
# 3  [{'label': 'display', 'lat': 43.65431754076345...     43.654318
# 4  [{'label': 'display', 'lat': 43.64929834396347...     43.649298
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.387042                   NaN             M5V 2T6             ON
# 1    -79.385931                   NaN             M5G 1R3             ON
# 2    -79.377591                   NaN             M5J 2T3             ON
# 3    -79.398650                   NaN             M5T 2E9             ON
# 4    -79.376431                   NaN             M5C 1E9             ON
#
#                               name    referralId venuePage.id
# 0                   360 Restaurant  v-1538918065          NaN
# 1  Hemispheres Restaurant & Bistro  v-1538918065          NaN
# 2                Marché Restaurant  v-1538918065     59869170
# 3           Rol San Restaurant 龍笙棧  v-1538918065          NaN
# 4            Victoria's Restaurant  v-1538918065    498556908

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0                                      360 Restaurant
# 1                     Hemispheres Restaurant & Bistro
# 2                                   Marché Restaurant
# 3                              Rol San Restaurant 龍笙棧
# 4                               Victoria's Restaurant
# 5                             Swatow Restaurant 汕頭小食家
# 6                  Sky Dragon Chinese Restaurant 龍翔酒樓
# 7                      Goldstone Noodle Restaurant 金石
# 8                      The Hot House Restaurant & Bar
# 9                              Azure Restaurant & Bar
# 10                                  Tundra Restaurant
# 11                       Aroma Fine Indian Restaurant
# 12                           New Sky Restaurant 小沙田食家
# 13                           Ka Chi Korean Restaurant
# 14                Richtree Natural Market Restaurants
# 15                              ONE Restaurant/Lounge
# 16     Sassafraz | Cafe | Restaurant | Private Events
# 17                     Insomnia Restaurant and Lounge
# 18                            The Lakeview Restaurant
# 19                            Victor Restaurant & Bar
# 20                        Woodlot Restaurant & Bakery
# 21               Konnichiwa Japanese Restaurant こんにちわ
# 22                                  Studio Restaurant
# 23                                   Union Restaurant
# 24                             The Senator Restaurant
# 25                 North-East Chinese Restaurant 華北美食
# 26                      Hong Shing Chinese Restaurant
# 27                           Noble Chinese Restaurant
# 28                    Bright Pearl Seafood Restaurant
# 29                               Ricarda's Restaurant
# 30  KAKA All You Can Eat Japanese Restaurant (Down...
# 31            Tasty's Caribbean Restaurant & Catering
# 32                                  SCHOOL Restaurant
# 33                  El Rancho Restaurant & Night Club
# 34                  Kensington Cornerstone Restaurant
# 35                               Montecito Restaurant
# 36                    Dim Sum King Seafood Restaurant
# 37                         Matisse Restaurant And Bar
# 38                        Cottage Restaurant & Lounge
# 39                                  Evviva Restaurant
# 40                         Hendricks Restaurant & Bar
# 41                                  Arriba Restaurant
# 42                          Korean Village Restaurant
# 43               Sunrise House Korean Restaurant 해뜨는집
# 44                              Sightlines Restaurant
# 45                      Micheal's Restaurant and Deli
# 46                    Mapo Korean BBQ Restaurant 마포상회
# 47                           Fune Japanese Restaurant
# 48                       Yueh Tung Chinese Restaurant
# 49                                    Cali Restaurant
#
#                   categories                      address  cc     city  \
# 0                   Wine Bar                     CN Tower  CA  Toronto
# 1        American Restaurant          110 Chestnut Street  CA  Toronto
# 2                 Restaurant                  181 Bay St.  CA  Toronto
# 3         Dim Sum Restaurant             323 Spadina Ave.  CA  Toronto
# 4                 Restaurant          37 King Street East  CA  Toronto
# 5         Chinese Restaurant             309 Spadina Ave.  CA  Toronto
# 6         Dim Sum Restaurant             280 Spadina Ave.  CA  Toronto
# 7               Noodle House              266 Spadina Ave  CA  Toronto
# 8        American Restaurant                 35 Church St  CA  Toronto
# 9                 Restaurant                225 Frnt St W  CA  Toronto
# 10                Restaurant     145 Richmond Street West  CA  Toronto
# 11         Indian Restaurant               287 King St. W  CA  Toronto
# 12        Chinese Restaurant             353 Spadina Ave.  CA  Toronto
# 13         Korean Restaurant              8 St Andrew St.  CA  Toronto
# 14                Restaurant                14 Queen St W  CA  Toronto
# 15   New American Restaurant            116 Yorkville Ave  CA  Toronto
# 16               Event Space        100 Cumberland Street  CA  Toronto
# 17                Restaurant            563 Bloor St West  CA  Toronto
# 18                     Diner            1132 Dundas St. W  CA  Toronto
# 19                       Bar             30 Mercer Street  CA  Toronto
# 20   New American Restaurant          293 Palmerston Ave.  CA  Toronto
# 21       Japanese Restaurant               31 Baldwin St.  CA  Toronto
# 22            Breakfast Spot               389 Church St.  CA  Toronto
# 23         French Restaurant            72 Ossington Ave.  CA  Toronto
# 24                     Diner          249 Victoria Street  CA  Toronto
# 25        Chinese Restaurant               476 Dundas St.  CA  Toronto
# 26        Chinese Restaurant              195 Dundas St W  CA  Toronto
# 27        Chinese Restaurant             530 Dundas St. W  CA  Toronto
# 28        Chinese Restaurant       346-348 Spadina Avenue  CA  Toronto
# 29  Mediterranean Restaurant             134 Peter Street  CA  Toronto
# 30       Japanese Restaurant               655 Bay Street  CA  Toronto
# 31      Caribbean Restaurant              405 Spadina Ave  CA  Toronto
# 32            Breakfast Spot               70 Fraser Ave.  CA  Toronto
# 33                 Nightclub              430 College St.  CA  Toronto
# 34            Breakfast Spot           2A Kensington Ave.  CA  Toronto
# 35                Restaurant            299 Adelaide St W  CA  Toronto
# 36        Dim Sum Restaurant  421 Dundas St. W, 3rd Floor  CA  Toronto
# 37                Restaurant                 90 Bloor St.  CA  Toronto
# 38           Thai Restaurant               338 Jarvis St.  CA  Toronto
# 39             Deli / Bodega           25 Lower Simcoe St  CA  Toronto
# 40                Restaurant              Yonge And Queen  CA  Toronto
# 41                Restaurant              1 Blue Jays Way  CA  Toronto
# 42         Korean Restaurant        628 Bloor Street West  CA  Toronto
# 43         Korean Restaurant        661 Bloor Street West  CA  Toronto
# 44       American Restaurant                Rogers Centre  CA  Toronto
# 45                       Bar               566 Queen St W  CA  Toronto
# 46         Korean Restaurant               680 Bloor St W  CA  Toronto
# 47       Japanese Restaurant               100 Simcoe St.  CA  Toronto
# 48        Chinese Restaurant            126 Elizabeth St.  CA  Toronto
# 49     Vietnamese Restaurant            179 Dundas St. W.  CA  Toronto
#
#    country                       crossStreet  distance  \
# 0   Canada                   301 Front St. W      1271
# 1   Canada                               NaN       145
# 2   Canada               in Brookfield Place      1077
# 3   Canada                     at D'Arcy St.       922
# 4   Canada  at Le Meridien King Edward Hotel      1011
# 5   Canada    btwn Dundas St. W & D'Arcy St.       896
# 6   Canada                  at Dundas St. W.       892
# 7   Canada                    at Willison Sq       892
# 8   Canada                     at Front St E      1233
# 9   Canada                               NaN      1039
# 10  Canada                    Hilton Toronto       458
# 11  Canada                       at John St.       857
# 12  Canada                               NaN       953
# 13  Canada                   at Spadina Ave.       972
# 14  Canada                               NaN       581
# 15  Canada                  at Hazelton Ave.      1937
# 16  Canada                        Bellair St      1849
# 17  Canada                       Bathurst St      2284
# 18  Canada                 at Ossington Ave.      2719
# 19  Canada                        at John St       979
# 20  Canada                    at College St.      1841
# 21  Canada                        McCaul St.       549
# 22  Canada                    at Carlton St.      1052
# 23  Canada                       Queen St. W      2755
# 24  Canada    btwn Dundas St E and Shuter St       671
# 25  Canada                             Huron       767
# 26  Canada                 at University Ave       107
# 27  Canada                   at Spadina Ave.       946
# 28  Canada                               NaN       960
# 29  Canada                               NaN       783
# 30  Canada                ( Bay st & Elm st)       468
# 31  Canada                        College St      1019
# 32  Canada                    at Liberty St.      3489
# 33  Canada                   at Bathurst St.      1630
# 34  Canada                      Dundas St. W      1035
# 35  Canada                          Peter St       769
# 36  Canada                               NaN       673
# 37  Canada                         Yonge St.      1858
# 38  Canada           north of Carlton Street      1284
# 39  Canada                 Grand Trunk Cresc      1411
# 40  Canada                               NaN       628
# 41  Canada      inside the Renaissance Hotel      1397
# 42  Canada                               NaN      2481
# 43  Canada                           Manning      2564
# 44  Canada                               NaN      1383
# 45  Canada                               NaN      1507
# 46  Canada                               NaN      2632
# 47  Canada                      at Pearl St.       609
# 48  Canada                        Dundas St.       210
# 49  Canada                       at Chestnut       140
#
#                                      formattedAddress  \
# 0   [CN Tower (301 Front St. W), Toronto ON M5V 2T...
# 1   [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 2   [181 Bay St. (in Brookfield Place), Toronto ON...
# 3   [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 4   [37 King Street East (at Le Meridien King Edwa...
# 5   [309 Spadina Ave. (btwn Dundas St. W & D'Arcy ...
# 6   [280 Spadina Ave. (at Dundas St. W.), Toronto ...
# 7   [266 Spadina Ave (at Willison Sq), Toronto ON ...
# 8   [35 Church St (at Front St E), Toronto ON M5E ...
# 9         [225 Frnt St W, Toronto ON M5V 2X3, Canada]
# 10  [145 Richmond Street West (Hilton Toronto), To...
# 11  [287 King St. W (at John St.), Toronto ON M5V ...
# 12     [353 Spadina Ave., Toronto ON M5T 2G3, Canada]
# 13  [8 St Andrew St. (at Spadina Ave.), Toronto ON...
# 14        [14 Queen St W, Toronto ON M5H 3X4, Canada]
# 15  [116 Yorkville Ave (at Hazelton Ave.), Toronto...
# 16  [100 Cumberland Street (Bellair St), Toronto O...
# 17  [563 Bloor St West (Bathurst St), Toronto ON M...
# 18  [1132 Dundas St. W (at Ossington Ave.), Toront...
# 19  [30 Mercer Street (at John St), Toronto ON M5V...
# 20  [293 Palmerston Ave. (at College St.), Toronto...
# 21  [31 Baldwin St. (McCaul St.), Toronto ON M5T 1...
# 22  [389 Church St. (at Carlton St.), Toronto ON M...
# 23  [72 Ossington Ave. (Queen St. W), Toronto ON, ...
# 24  [249 Victoria Street (btwn Dundas St E and Shu...
# 25       [476 Dundas St. (Huron), Toronto ON, Canada]
# 26  [195 Dundas St W (at University Ave), Toronto ...
# 27  [530 Dundas St. W (at Spadina Ave.), Toronto O...
# 28  [346-348 Spadina Avenue, Toronto ON M5T 2G2, C...
# 29     [134 Peter Street, Toronto ON M5V 2H2, Canada]
# 30  [655 Bay Street (( Bay st & Elm st)), Toronto ...
# 31  [405 Spadina Ave (College St), Toronto ON M5T ...
# 32  [70 Fraser Ave. (at Liberty St.), Toronto ON M...
# 33  [430 College St. (at Bathurst St.), Toronto ON...
# 34  [2A Kensington Ave. (Dundas St. W), Toronto ON...
# 35  [299 Adelaide St W (Peter St), Toronto ON M5V ...
# 36  [421 Dundas St. W, 3rd Floor, Toronto ON M5T 1...
# 37  [90 Bloor St. (Yonge St.), Toronto ON M4W 1A7,...
# 38  [338 Jarvis St. (north of Carlton Street), Tor...
# 39  [25 Lower Simcoe St (Grand Trunk Cresc), Toron...
# 40      [Yonge And Queen, Toronto ON M5G 2H6, Canada]
# 41  [1 Blue Jays Way (inside the Renaissance Hotel...
# 42        [628 Bloor Street West, Toronto ON, Canada]
# 43  [661 Bloor Street West (Manning), Toronto ON, ...
# 44                [Rogers Centre, Toronto ON, Canada]
# 45               [566 Queen St W, Toronto ON, Canada]
# 46       [680 Bloor St W, Toronto ON M6G 1L2, Canada]
# 47  [100 Simcoe St. (at Pearl St.), Toronto ON, Ca...
# 48  [126 Elizabeth St. (Dundas St.), Toronto ON, C...
# 49  [179 Dundas St. W. (at Chestnut), Toronto ON M...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 43.64253731714456...  43.642537 -79.387042
# 1   [{'label': 'display', 'lat': 43.65488413420439...  43.654884 -79.385931
# 2   [{'label': 'display', 'lat': 43.64723237089591...  43.647232 -79.377591
# 3   [{'label': 'display', 'lat': 43.65431754076345...  43.654318 -79.398650
# 4   [{'label': 'display', 'lat': 43.64929834396347...  43.649298 -79.376431
# 5   [{'label': 'display', 'lat': 43.65386562507761...  43.653866 -79.398334
# 6   [{'label': 'display', 'lat': 43.65278331265585...  43.652783 -79.398174
# 7   [{'label': 'display', 'lat': 43.6522783893466,...  43.652278 -79.398039
# 8   [{'label': 'display', 'lat': 43.64868288754344...  43.648683 -79.373741
# 9   [{'label': 'display', 'lat': 43.64474919591934...  43.644749 -79.385113
# 10  [{'label': 'display', 'lat': 43.65000998764964...  43.650010 -79.385608
# 11  [{'label': 'display', 'lat': 43.64646252150344...  43.646463 -79.389644
# 12  [{'label': 'display', 'lat': 43.65533674412141...  43.655337 -79.398897
# 13  [{'label': 'display', 'lat': 43.65430655228665...  43.654307 -79.399277
# 14  [{'label': 'display', 'lat': 43.65261436174172...  43.652614 -79.380231
# 15  [{'label': 'display', 'lat': 43.67080936827553...  43.670809 -79.393272
# 16  [{'label': 'display', 'lat': 43.67034226367314...  43.670342 -79.391041
# 17  [{'label': 'display', 'lat': 43.66517961801332...  43.665180 -79.410966
# 18  [{'label': 'display', 'lat': 43.64943515996231...  43.649435 -79.420390
# 19  [{'label': 'display', 'lat': 43.64563436248102...  43.645634 -79.391125
# 20  [{'label': 'display', 'lat': 43.655765, 'lng':...  43.655765 -79.409929
# 21  [{'label': 'display', 'lat': 43.65607891650737...  43.656079 -79.393371
# 22  [{'label': 'display', 'lat': 43.66150015906530...  43.661500 -79.379319
# 23  [{'label': 'display', 'lat': 43.64585979013257...  43.645860 -79.419532
# 24  [{'label': 'display', 'lat': 43.65564091455335...  43.655641 -79.379199
# 25  [{'label': 'display', 'lat': 43.6531846832903,...  43.653185 -79.396677
# 26  [{'label': 'display', 'lat': 43.65492521335936...  43.654925 -79.387089
# 27  [{'label': 'display', 'lat': 43.65272353176442...  43.652724 -79.398839
# 28  [{'label': 'display', 'lat': 43.654219, 'lng':...  43.654219 -79.399125
# 29  [{'label': 'display', 'lat': 43.64855585967538...  43.648556 -79.393432
# 30  [{'label': 'display', 'lat': 43.65749652942284...  43.657497 -79.384047
# 31  [{'label': 'display', 'lat': 43.656794, 'lng':...  43.656794 -79.399251
# 32  [{'label': 'display', 'lat': 43.6377753703417,...  43.637775 -79.424297
# 33  [{'label': 'display', 'lat': 43.65667340500913...  43.656673 -79.407101
# 34  [{'label': 'display', 'lat': 43.65280330843737...  43.652803 -79.399958
# 35  [{'label': 'display', 'lat': 43.64764401408166...  43.647644 -79.391069
# 36  [{'label': 'display', 'lat': 43.65343007039644...  43.653430 -79.395539
# 37  [{'label': 'display', 'lat': 43.67057375344845...  43.670574 -79.384856
# 38  [{'label': 'display', 'lat': 43.66277006654972...  43.662770 -79.376894
# 39  [{'label': 'display', 'lat': 43.64157991761808...  43.641580 -79.383456
# 40  [{'label': 'display', 'lat': 43.652887, 'lng':...  43.652887 -79.379542
# 41  [{'label': 'display', 'lat': 43.64147925628281...  43.641479 -79.389074
# 42  [{'label': 'display', 'lat': 43.66449791303206...  43.664498 -79.414367
# 43  [{'label': 'display', 'lat': 43.66418287914217...  43.664183 -79.415746
# 44  [{'label': 'display', 'lat': 43.64163507221119...  43.641635 -79.389365
# 45  [{'label': 'display', 'lat': 43.64728932229506...  43.647289 -79.403493
# 46  [{'label': 'display', 'lat': 43.66409588590324...  43.664096 -79.416738
# 47  [{'label': 'display', 'lat': 43.64851365544565...  43.648514 -79.386457
# 48  [{'label': 'display', 'lat': 43.65528126342919...  43.655281 -79.385337
# 49  [{'label': 'display', 'lat': 43.65506808, 'lng...  43.655068 -79.386375
#
#               neighborhood postalCode state                        id
# 0                      NaN    M5V 2T6    ON  4ad4c05cf964a520dff520e3
# 1                      NaN    M5G 1R3    ON  4ad4c05ff964a52048f720e3
# 2                      NaN    M5J 2T3    ON  4baa4b39f964a520ec5b3ae3
# 3                      NaN    M5T 2E9    ON  4ad4c060f964a5207ff720e3
# 4                      NaN    M5C 1E9    ON  4ad4c05cf964a52006f620e3
# 5                      NaN    M5T 2E6    ON  4ae29812f964a520288f21e3
# 6                      NaN        NaN    ON  4b072e9df964a52009f922e3
# 7                      NaN    M5T 2E4    ON  4b266f05f964a520657b24e3
# 8                      NaN    M5E 1T3    ON  4ada5d5bf964a520e92121e3
# 9   Entertainment District    M5V 2X3    ON  4b223f5af964a520ba4424e3
# 10                     NaN    M5H 2L2    ON  50ca02c0245f2d4aa8c2b313
# 11                     NaN    M5V 1J5    ON  4aef8854f964a5201cd921e3
# 12                     NaN    M5T 2G3    ON  4b074bb1f964a52077fb22e3
# 13                     NaN    M5T 1K6    ON  4ba2d00cf964a5203e1b38e3
# 14                     NaN    M5H 3X4    ON  4b295e10f964a520ba9d24e3
# 15                     NaN        NaN    ON  4b02a076f964a520234922e3
# 16                     NaN    M5R 1A6    ON  4ad4c05cf964a520cef520e3
# 17                     NaN    M5S 1Y6    ON  4ad4c05cf964a520cdf520e3
# 18                     NaN    M6J 1X2    ON  4b22e814f964a520175024e3
# 19                     NaN    M5V 1H3    ON  4ad4c05df964a5203ff620e3
# 20                     NaN    M6J 2J3    ON  4cc3a79bbde8f04d0ddba64b
# 21                     NaN    M5T 1L1    ON  4b6a1058f964a52028c52be3
# 22                     NaN        M5B    ON  4bd47e6fcfa7b7139f2924da
# 23                     NaN        NaN    ON  4ada6d8df964a520832221e3
# 24                     NaN    M5B 1T8    ON  4ad7929cf964a520500c21e3
# 25                     NaN        NaN    ON  4d06c1ccc2e53704428cc567
# 26                     NaN    M5G 1C7    ON  4b2027b5f964a520f82d24e3
# 27                     NaN    M5T 1H3    ON  4b7b22a4f964a52085532fe3
# 28                     NaN    M5T 2G2    ON  4ad4c05ff964a5200bf720e3
# 29                     NaN    M5V 2H2    ON  5792bb19498e1e1d0b52f008
# 30                     NaN    M5G 1Z4    ON  5a62412b1108ba191da5ba06
# 31                     NaN    M5T 2G6    ON  5b1c3098f96b2c002c5eb0c5
# 32                     NaN    M6K 3C5    ON  4ae094a7f964a5208f8021e3
# 33                     NaN    M5T 1T3    ON  4ad4c05df964a52076f620e3
# 34                     NaN    M5T 2J7    ON  4bce1ec0cc8cd13a9ac8c3cf
# 35                     NaN    M5V 1P7    ON  537e313d498e9e9e015f3018
# 36                     NaN    M5T 1G6    ON  4ddbe8697d8b771c0b09b885
# 37                     NaN    M4W 1A7    ON  4b4d3b51f964a520e4ce26e3
# 38                     NaN    M4Y 2G6    ON  4ad4c05ff964a52018f720e3
# 39                     NaN    M5J 3A1    ON  562922be498e2c6aad0e6091
# 40                     NaN    M5G 2H6    ON  5a8b24b2018cbb6c4ca70dae
# 41                     NaN    M5V 1J4    ON  4ad4c060f964a5208af720e3
# 42                     NaN        NaN    ON  4b11b1f2f964a520778223e3
# 43                     NaN        NaN    ON  4b19c8b7f964a52017e423e3
# 44                     NaN        NaN    ON  4bc3ad5e461576b0db037f32
# 45                     NaN        NaN    ON  4c47d78c1ddec92817ca9e32
# 46               Koreatown    M6G 1L2    ON  5a60f513a6031c579d573413
# 47                     NaN        NaN    ON  4afa1f33f964a520e91622e3
# 48                     NaN        NaN    ON  52a7ae41498eed3af4d0a3fa
# 49                     NaN        M5G    ON  4c476d6719fde21e32410876

# %%
dataframe_filtered.name
# Out:
# 0                                        360 Restaurant
# 1                       Hemispheres Restaurant & Bistro
# 2                                     Marché Restaurant
# 3                                Rol San Restaurant 龍笙棧
# 4                                 Victoria's Restaurant
# 5                               Swatow Restaurant 汕頭小食家
# 6                    Sky Dragon Chinese Restaurant 龍翔酒樓
# 7                        Goldstone Noodle Restaurant 金石
# 8                                Azure Restaurant & Bar
# 9                        The Hot House Restaurant & Bar
# 10                                    Tundra Restaurant
# 11                         Aroma Fine Indian Restaurant
# 12                             Ka Chi Korean Restaurant
# 13                             New Sky Restaurant 小沙田食家
# 14                  Richtree Natural Market Restaurants
# 15                                ONE Restaurant/Lounge
# 16       Sassafraz | Cafe | Restaurant | Private Events
# 17                       Insomnia Restaurant and Lounge
# 18                                     Union Restaurant
# 19                              The Lakeview Restaurant
# 20                              Victor Restaurant & Bar
# 21                 Konnichiwa Japanese Restaurant こんにちわ
# 22                          Woodlot Restaurant & Bakery
# 23                                    Studio Restaurant
# 24                   North-East Chinese Restaurant 華北美食
# 25                               The Senator Restaurant
# 26                        Hong Shing Chinese Restaurant
# 27                      Bright Pearl Seafood Restaurant
# 28    KAKA All You Can Eat Japanese Restaurant (Down...
# 29                             Noble Chinese Restaurant
# 30              Tasty's Caribbean Restaurant & Catering
# 31                                 Ricarda's Restaurant
# 32                    El Rancho Restaurant & Night Club
# 33                                    SCHOOL Restaurant
# 34                    Kensington Cornerstone Restaurant
# 35                                 Montecito Restaurant
# 36                      Dim Sum King Seafood Restaurant
# 37                           Matisse Restaurant And Bar
# 38                          Cottage Restaurant & Lounge
# 39                           Hendricks Restaurant & Bar
# 40                                    Evviva Restaurant
# 41                            Korean Village Restaurant
# 42                                    Arriba Restaurant
# 43                 Sunrise House Korean Restaurant 해뜨는집
# 44                                Sightlines Restaurant
# 45                        Micheal's Restaurant and Deli
# 46                      Mapo Korean BBQ Restaurant 마포상회
# 47                             Fune Japanese Restaurant
# 48                         Yueh Tung Chinese Restaurant
# 49                                      Cali Restaurant
# Name: name, dtype: object

# %% [markdown]
# ### Let's explore some Asean restaurant

# %%
asean_id = [3,5,6,7,11,12,13,24,26,28,29,36,41,43,45,46,47,48]
len(asean_id)
# Out:
# 18

# %%
Nr = len(asean_id)

rating_all = []
likes_all = []
tip_all = []
price_all = []


for i in range(Nr):
    venue_id = dataframe.id[i]
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
    result = requests.get(url).json()
    rating_all.append(result['response']['venue']['rating'])
    likes_all.append(result['response']['venue']['likes']['count'])
    tip_all.append(result['response']['venue']['stats']['tipCount'])
    price_all.append(result['response']['venue']['price']['message'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-152-a59e719d7f54> in <module>()
#      11     url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
#      12     result = requests.get(url).json()
# ---> 13     rating_all.append(result['response']['venue']['rating'])
#      14     likes_all.append(result['response']['venue']['likes']['count'])
#      15     tip_all.append(result['response']['venue']['stats']['tipCount'])
#
# KeyError: 'venue'

# %%
 # _Kyoto House Japanese Restaurant_ --- id=4ae4b055f964a520229d21e3
venue_id = dataframe.id[3]
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
result = requests.get(url).json()


print(result['response']['venue']['rating'])
print(result['response']['venue']['likes']['count'])
print(result['response']['venue']['stats']['tipCount'])
print(result['response']['venue']['price']['message'])
# print(result['response']['venue']['rating'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-167-54b2c10fcec8> in <module>()
#       3 url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
#       4 result = requests.get(url).json()
# ----> 5 print(result['response']['venue']['rating'])
#       6 print(result['response']['venue']['likes']['count'])
#       7 print(result['response']['venue']['stats']['tipCount'])
#
# KeyError: 'venue'

# %%
result
# Out:
# {'meta': {'code': 429,
#   'errorDetail': 'Quota exceeded',
#   'errorType': 'quota_exceeded',
#   'requestId': '5bba29e49fb6b75291787df0'},
#  'response': {}}

# %%
# Out:
# 7.6
# 30
# 10
# Cheap

# %%
# create map of Manhattan using latitude and longitude values
map_restaurant_Toronto = folium.Map(location=[latitude, longitude], zoom_start=14)

# add markers to map
for lat, lng, label in zip(dataframe_filtered['lat'], dataframe_filtered['lng'], dataframe_filtered['name']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_restaurant_Toronto)  
    
map_restaurant_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
user_id = '484542633' # user ID with most agree counts and complete profile

url = 'https://api.foursquare.com/v2/users/{}?client_id={}&client_secret={}&v={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION) # define URL

# send GET request
results = requests.get(url).json()
user_data = results['response']['user']

# display features associated with user
user_data.keys()
# Out:
# dict_keys(['id', 'firstName', 'lastName', 'gender', 'canonicalUrl', 'photo', 'friends', 'tips', 'homeCity', 'bio', 'contact', 'photos', 'type', 'mayorships', 'checkins', 'lists', 'lenses'])
